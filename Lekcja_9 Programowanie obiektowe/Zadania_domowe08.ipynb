# %% [markdown]
# Zadanie 9
# Napisz funkcję normalize_minmax(dane) , która normalizuje listę liczb do zakresu [0, 1]
# używając metody min-max.
# Dataset:
# Wymagania:
# Oczekiwany rezultat:
# (średnie)
# wynagrodzenia = [3500, 4200, 5800, 7200, 9500, 4800, 6100]
# Wzór: (x - min) / (max - min)
# Funkcja zwraca nową listę znormalizowanych wartości
# Zaokrąglij do 3 miejsc po przecinku
# Lista wartości w zakresie [0.0, 1.0

# %%
def normalize_minmax(dane):
    
    wartosc_min = min(dane)
    wartosc_max = max(dane)
    
    zakres = wartosc_max - wartosc_min
    
    # Jeśli wszystkie liczby są takie same, zwracamy listę zer (unikamy dzielenia przez 0)
    if zakres == 0:
        return [0.0 for _ in dane]
    
    # Normalizacja zgodnie ze wzorem: (x - min) / (max - min)
    return [round((x - v_min) / zakres, 3) for x in dane]

# Dataset
wynagrodzenia = [3500, 4200, 5800, 7200, 9500, 4800, 6100]

# Wywołanie funkcji
znormalizowane_wynagrodzenia = normalize_minmax(wynagrodzenia)

# Wynik
print(znormalizowane_wynagrodzenia)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 19
#      16 wynagrodzenia = [3500, 4200, 5800, 7200, 9500, 4800, 6100]
#      18 # Wywołanie funkcji
# ---> 19 znormalizowane_wynagrodzenia = normalize_minmax(wynagrodzenia)
#      21 # Wynik
#      22 print(znormalizowane_wynagrodzenia)
#
# Cell In[3], line 13, in normalize_minmax(dane)
#      10     return [0.0 for _ in dane]
#      12 # Normalizacja zgodnie ze wzorem: (x - min) / (max - min)
# ---> 13 return [round((x - v_min) / zakres, 3) for x in dane]
#
# Cell In[3], line 13, in <listcomp>(.0)
#      10     return [0.0 for _ in dane]
#      12 # Normalizacja zgodnie ze wzorem: (x - min) / (max - min)
# ---> 13 return [round((x - v_min) / zakres, 3) for x in dane]
#
# NameError: name 'v_min' is not defined
